# %%
# !pip freeze > requirements.txt

# %%
# !type requirements.txt
# Out:
# absl-py==2.1.0
# annotated-types==0.7.0
# anyio==4.2.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# astunparse==1.6.3
# async-lru==2.0.4
# attrs==23.2.0
# Babel==2.14.0
# beautifulsoup4==4.12.3
# bleach==6.1.0
# blinker==1.9.0
# cachetools==5.3.2
# certifi==2023.11.17
# cffi==1.16.0
# charset-normalizer==3.3.2
# click==8.1.3
# colorama==0.4.6
# comm==0.2.1
# contourpy==1.2.0
# cycler==0.12.1
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# distlib==0.3.9
# distro==1.9.0
# et_xmlfile==2.0.0
# executing==2.0.1
# fastjsonschema==2.19.1
# filelock==3.18.0
# Flask==3.1.0
# flatbuffers==23.5.26
# fonttools==4.47.2
# fqdn==1.5.1
# frozendict==2.4.4
# fsspec==2025.5.1
# gast==0.5.4
# google-auth==2.27.0
# google-auth-oauthlib==1.2.0
# google-pasta==0.2.0
# groq==0.30.0
# grpcio==1.60.0
# h11==0.16.0
# h5py==3.10.0
# html5lib==1.1
# httpcore==1.0.9
# httpx==0.28.1
# huggingface-hub==0.33.2
# idna==3.6
# ipykernel==6.29.0
# ipython==8.21.0
# ...

# %%
# !pip install pipreqs
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/798.3 kB ? eta -:--:--
#    ------------- -------------------------- 262.1/798.3 kB ? eta -:--:--
#    ---------------------------------------- 798.3/798.3 kB 2.9 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13774 sha256=bf670e868f0000e7c24647d2e98534a24462959f87d56c4de2362258c125ea10
#   Stored in directory: c:\users\suhani singh\appdata\local\pip\cache\wheels\1a\b0\8c\4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built docopt
# ...
#
#    ------------- -------------------------- 2/6 [backcall]
#    -------------------- ------------------- 3/6 [yarg]
#    -------------------- ------------------- 3/6 [yarg]
#   Attempting uninstall: ipython
#    -------------------- ------------------- 3/6 [yarg]
#     Found existing installation: ipython 8.21.0
# ...

# %%
# !pipreqs "C:/Users/Suhani Singh/classification.log"
# Out:
# INFO: Not scanning for jupyter notebooks.
# WARNING: Import named "groq" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "groq" was resolved to "groq:0.30.0" package (https://pypi.org/project/groq/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "python-dotenv" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "python-dotenv" was resolved to "python-dotenv:1.1.1" package (https://pypi.org/project/python-dotenv/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# INFO: Successfully saved requirements file in C:/Users/Suhani Singh/classification.log\requirements.txt
